# %% [markdown]
# ### Handling of tiff files from ECOSTRESS

# %%
import rasterio
from rasterio.plot import show
import numpy as np

# %%
import os

# %%
path = '/Users/gaurav/UAH/ECOSTRESS_and_urban_surface_dataset/Madison/ECOSTRESS/geotiff_clipped_stateplane/'
os.chdir(path)

# %%
file = os.listdir()[4]
fp = rasterio.open(file)

# %%
show(fp)
# Out:
# <AxesSubplot:>

# %%
arr = fp.read()

# %%
x = arr*0.02-273.15
x[0]
# Out:
# array([[-273.15  , -273.15  , -273.15  , ..., -273.15  , -273.15  ,
#         -273.15  ],
#        [-273.15  , -273.15  , -273.15  , ..., -273.15  , -273.15  ,
#         -273.15  ],
#        [-273.15  , -273.15  , -273.15  , ..., -273.15  , -273.15  ,
#         -273.15  ],
#        ...,
#        [-273.15  , -273.15  , -272.9062, ..., -273.15  , -273.15  ,
#         -273.15  ],
#        [-273.15  , -273.15  , -272.8958, ..., -273.15  , -273.15  ,
#         -273.15  ],
#        [-273.15  , -273.15  , -272.9154, ..., -273.15  , -273.15  ,
#         -273.15  ]])

# %%
import matplotlib.pyplot as plt
plt.imshow(x[0])
