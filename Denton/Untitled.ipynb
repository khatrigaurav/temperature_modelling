# %%
import requests
import pandas as pd


headers = {
    'accept': 'application/json',
    'Authorization': 'Bearer 63c99676f8d0f9304b0cdf3f|1c1d6eb97169c8eaef44d5dadc2d0f66'
}

params = {
    'lat_ne': '43.16428113592413',
    'lon_ne': '-89.27314688519613',
    'lat_sw': '43.01322538249216',
    'lon_sw': '-89.53534080698618',
    'required_data': 'temperature',
    'filter': 'false',
}

response = requests.get('https://api.netatmo.com/api/getpublicdata', params=params, headers=headers).json()

# %%
def get_module_ids(response):
    body = response.get('body')
    df = pd.DataFrame(body)
#     df['module_id'] = [k if 'NAModule1' in v else 'NA' for k,v in value.items() for value in df['module_types'].values]
    df['module_id'] = 'NA'
    df['module_type'] = 'NA'
    df['module_id'] = [k for value in df['module_types'].values for k,v in value.items() if 'NAModule1' in v ]
    df['module_type'] = [v for value in df['module_types'].values for k,v in value.items() if 'NAModule1' in v ]
    df = df[df.module_type == 'NAModule1']
    df['device_info'] = df['_id']+','+ df['module_id']

    
    return df

# %%
pd.DataFrame(body)
# Out:
#                   _id                                              place  \
# 0   70:ee:50:65:25:40  {'location': [-89.213068, 43.095288], 'timezon...
# 1   70:ee:50:06:11:40  {'location': [-89.2153407, 43.1107383], 'timez...
# 2   70:ee:50:84:2b:d2  {'location': [-89.2836887, 43.1660273], 'timez...
# 3   70:ee:50:06:9e:b4  {'location': [-89.313558, 43.073576], 'timezon...
# 4   70:ee:50:00:96:ea  {'location': [-89.3310524, 43.0958646], 'timez...
# 5   70:ee:50:2a:e1:a6  {'location': [-89.3501567840523, 43.1277029077...
# 6   70:ee:50:20:c2:c8  {'location': [-89.384012, 43.138837], 'timezon...
# 7   70:ee:50:6b:87:74  {'location': [-89.394303, 43.007885], 'timezon...
# 8   70:ee:50:06:9d:34  {'location': [-89.317055, 43.00042], 'timezone...
# 9   70:ee:50:71:37:5c  {'location': [-89.303895, 43.019654], 'timezon...
# 10  70:ee:50:1b:20:40  {'location': [-89.408794, 43.06395], 'timezone...
# 11  70:ee:50:05:f7:ac  {'location': [-89.5094221, 43.0704332], 'timez...
# ...

# %%
p = [list(k) for k in [x.split(',') for x in dfx.device_info]]

# %%
df.place[0]
# Out:
# {'location': [-89.213068, 43.095288],
#  'timezone': 'America/Chicago',
#  'country': 'US',
#  'altitude': 274,
#  'city': 'Village of Cottage Grove',
#  'street': 'Lindsay Way'}

# %%
dfx.loc[dfx.device_info==dfx.device_info[2]]['place'].values[0].get('location')
# Out:
# [-89.2836887, 43.1660273]

# %%
dfx.loc[2]['place']
# Out:
# {'location': [-89.2836887, 43.1660273],
#  'timezone': 'America/Chicago',
#  'country': 'US',
#  'altitude': 298,
#  'city': 'Sun Prairie',
#  'street': 'Pleasant Street'}

# %%
import requests

def get_netatmo_bearer_token():
    url = "https://api.netatmo.com/oauth2/token"
    payload = {
        "grant_type": "password",
        "client_id": "6426523a81bfec4f400a0677",
        "client_secret": "jN3ZL2OLDB7QRpNkRG4aRrEL118Cirz8",
        "username": "gaurav113.gk@gmail.com",
        "password": "T@sr.!s9T5JntBK",
    }
    response = requests.post(url, data=payload)
    if response.status_code == 200:
        return response.json()["access_token"],response.json()["refresh_token"],
    else:
        print(response)
        raise Exception("Failed to get bearer token")

# %%
get_netatmo_bearer_token()
# Out:
# {'access_token': '63c99676f8d0f9304b0cdf3f|2ffd4706f6b566c2c1272fc7e7a7856e',
#  'refresh_token': '63c99676f8d0f9304b0cdf3f|80a01b6cd6565191a48040829611320a',
#  'scope': ['read_station'],
#  'expires_in': 10800,
#  'expire_in': 10800}
